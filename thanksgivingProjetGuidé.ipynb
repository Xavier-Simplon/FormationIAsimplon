# %%
import pandas as pd
import numpy as np

thanksgiving= pd.read_csv("/home/simplon/Téléchargements/thanksgiving.csv", encoding='latin-1')
thanksgiving.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
columns_thanksgiving = thanksgiving.columns

# %%
thanksgiving['Do you celebrate Thanksgiving?'].value_counts()
# Out:
# Yes    980
# No      78
# Name: Do you celebrate Thanksgiving?, dtype: int64

# %%
celebrate_thanksgiving_yes_bol= thanksgiving['Do you celebrate Thanksgiving?'] == 'Yes'
celebrate_thanksgiving_yes_bol.value_counts()
data=thanksgiving[celebrate_thanksgiving_yes_bol]
print(data)
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 3       4337933040                            Yes
# 4       4337931983                            Yes
# ...            ...                            ...
# 1053    4335944082                            Yes
# 1054    4335943173                            Yes
# 1055    4335943060                            Yes
# 1056    4335934708                            Yes
# 1057    4335894916                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 0                                                Turkey
# 1                                                Turkey
# 2                                                Turkey
# 3                                                Turkey
# 4                                              Tofurkey
# ...

# %%
thanksgiving['What is typically the main dish at your Thanksgiving dinner?'].value_counts()
# Out:
# Turkey                    859
# Other (please specify)     35
# Ham/Pork                   29
# Tofurkey                   20
# Chicken                    12
# Roast beef                 11
# I don't know                5
# Turducken                   3
# Name: What is typically the main dish at your Thanksgiving dinner?, dtype: int64

# %%
is_Tofurkey=data['What is typically the main dish at your Thanksgiving dinner?']=='Tofurkey'
tofurkey=data[is_Tofurkey]
tofurkey['Do you typically have gravy?']
# Out:
# 4      Yes
# 33     Yes
# 69      No
# 72      No
# 77     Yes
# 145    Yes
# 175    Yes
# 218     No
# 243    Yes
# 275     No
# 393    Yes
# 399    Yes
# 571    Yes
# 594    Yes
# 628     No
# 774     No
# 820     No
# 837    Yes
# 860     No
# 953    Yes
# Name: Do you typically have gravy?, dtype: object

# %%
apple_isnull= data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple']
apple_isnull=apple_isnull.isnull()

# %%
pumpkin_isnull= data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin']
pumpkin_isnull=pumpkin_isnull.isnull()

# %%
pecan_isnull=data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan'] 
pecan_isnull=pecan_isnull.isnull()

# %%
pies = apple_isnull & pumpkin_isnull & pecan_isnull

# %%
pies
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1053    False
# 1054    False
# 1055    False
# 1056     True
# 1057     True
# Length: 980, dtype: bool

# %%
pies.value_counts()
# Out:
# False    876
# True     104
# dtype: int64
